# %% [markdown]
# # Requeriments

# %%
import numpy                 as np
import pandas                as pd
import matplotlib.pyplot     as plt
import seaborn               as sns

from sklearn.preprocessing import StandardScaler
# Out:
# /pip_envs/Debuggers3.6/lib/python3.6/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Uploading data (dataXid)

# %%
df = pd.read_csv("/mnt/workstation/data/dataXid.csv")

# %%
id_cli = df['id_cli']
df = df.drop(['id_cli'], axis=1)

# %%
features = pd.DataFrame(df.dtypes)
features.columns = ['type']
features_f = features[features['type'] == 'float64'].index
features_o = features[features['type'] == 'object'].index
#features_i = features[features['type'] == 'int64'].index
#features_b = features[features['type'] == 'bool'].index

# %%
features_f
# Out:
# Index(['edad', 'mora_max', 'cant_moras_30_ult_12_meses',
#        'cant_moras_60_ult_12_meses', 'cant_moras_90_ult_12_meses',
#        'cupo_total_tc', 'codigo_ciiu', 'ctas_activas', 'ctas_embargadas',
#        'mediana_nom3', 'cant_mora_30_tdc_ult_3m_sf',
#        'cant_mora_30_consum_ult_3m_sf', 'mediana_nom3_desv',
#        'mediana_pen3_desv', 'ingreso_nompen_desv', 'ingreso_final_desv',
#        'ingreso_nompen', 'ingreso_final', 'cuota_de_vivienda',
#        'cuota_de_consumo', 'cuota_rotativos', 'cuota_de_sector_solidario',
#        'cuota_sector_real_comercio', 'pol_centr_ext', 'saldo_prom3_tdc_mdo',
#        'cupo_tc_mdo', 'cant_oblig_tot_sf', 'cant_cast_ult_12m_sr',
#        'saldo_no_rot_mdo', 'ind', 'gasto_familiar',
#        'ciudad_residencia_tag_ind', 'ciudad_residencia_tag_gasto_familiar',
#        'ciudad_residencia_tag_ingreso_nompen'],
#       dtype='object')

# %%
df[features_o].describe(include='all').T
# Out:
#                      count unique            top    freq
# genero             1092553      2              M  553563
# estado_civil       1092553      5        SOLTERO  605311
# nivel_academico    1092553      6  UNIVERSITARIO  720807
# profesion          1092553     79          OTROS  621847
# ocupacion          1092553     10       Empleado  697681
# ciudad_residencia  1092553   1434    BOGOTA D.C.  278442
# rep_calif_cred     1092553      8              A  324135

# %% [markdown]
# # One-Hot Encoding

# %%
df_onehot = pd.get_dummies(df, columns=features_o)
list(df_onehot.columns)
# Out:
# ['edad',
#  'mora_max',
#  'cant_moras_30_ult_12_meses',
#  'cant_moras_60_ult_12_meses',
#  'cant_moras_90_ult_12_meses',
#  'cupo_total_tc',
#  'codigo_ciiu',
#  'ctas_activas',
#  'ctas_embargadas',
#  'mediana_nom3',
#  'ind_mora_vigente',
#  'cartera_castigada',
#  'tenencia_tc',
#  'tiene_consumo',
#  'tiene_crediagil',
#  'tiene_ctas_activas',
#  'tiene_ctas_embargadas',
#  'pension_fopep',
#  'tiene_cred_hipo_1',
#  'tiene_cred_hipo_2',
#  'cant_mora_30_tdc_ult_3m_sf',
#  'cant_mora_30_consum_ult_3m_sf',
#  'mediana_nom3_desv',
#  'mediana_pen3_desv',
#  'ingreso_nompen_desv',
#  'ingreso_final_desv',
#  'ingreso_nompen',
#  'ingreso_final',
#  'cuota_de_vivienda',
#  'cuota_de_consumo',
#  'cuota_rotativos',
#  'cuota_de_sector_solidario',
#  'cuota_sector_real_comercio',
#  'pol_centr_ext',
#  'saldo_prom3_tdc_mdo',
#  'cupo_tc_mdo',
#  'cant_oblig_tot_sf',
#  'cant_cast_ult_12m_sr',
#  'saldo_no_rot_mdo',
#  'ind',
#  'gasto_familiar',
#  'estado_civil_tag_ind',
#  'nivel_academico_tag_ind',
#  'profesion_tag_ind',
#  'ocupacion_tag_ind',
#  'ciudad_residencia_tag_ind',
#  'rep_calif_cred_tag_ind',
#  'estado_civil_tag_gasto_familiar',
#  'nivel_academico_tag_gasto_familiar',
#  'profesion_tag_gasto_familiar',
#  'ocupacion_tag_gasto_familiar',
#  'ciudad_residencia_tag_gasto_familiar',
#  'rep_calif_cred_tag_gasto_familiar',
#  'estado_civil_tag_ingreso_nompen',
#  'nivel_academico_tag_ingreso_nompen',
#  'profesion_tag_ingreso_nompen',
#  'ocupacion_tag_ingreso_nompen',
#  'ciudad_residencia_tag_ingreso_nompen',
#  'rep_calif_cred_tag_ingreso_nompen',
#  'genero_tag',
#  'genero_F',
#  'genero_M',
#  'estado_civil_CASADO',
#  'estado_civil_DIVORCIADO',
#  'estado_civil_SOLTERO',
#  'estado_civil_UNION LIBRE',
#  'estado_civil_VIUDO',
#  'nivel_academico_BACHILLER',
#  'nivel_academico_ESPECIALIZACION',
#  'nivel_academico_NINGUNO',
#  'nivel_academico_PRIMARIO',
#  'nivel_academico_TECNOLOGO',
#  'nivel_academico_UNIVERSITARIO',
#  'profesion_ADMINISTRACION',
#  'profesion_AGRONOMIA',
#  'profesion_ARQUITECTURA',
#  'profesion_ARTES',
#  'profesion_AUXILIAR CONTABLE',
#  'profesion_AUXILIAR DE ENFERMERIA',
#  'profesion_AUXILIAR DE ODONTOLOGIA',
#  'profesion_AZAFATA',
#  'profesion_BACTERIOLOGIA',
#  'profesion_BIOLOGIA',
#  'profesion_CARRERA MILITAR',
#  'profesion_COMERCIO INTERNACIONAL',
#  'profesion_COMUNICACION SOCIAL',
#  'profesion_CONSTRUCCION CIVIL',
#  'profesion_CONTADURIA',
#  'profesion_DECORADORES Y DISEÑADORES COMERCIALES',
#  'profesion_DELINEANTE DE ARQUITECTURA',
#  'profesion_DERECHO',
#  'profesion_DISEÑO Y PUBLICIDAD',
#  'profesion_ECONOMIA',
#  'profesion_EDUCACION',
#  'profesion_ENFERMERIA',
#  'profesion_ESPEC EN PROBL DE PERS Y ORIENTA ANAL. PRP',
#  'profesion_FILOSOFIA Y LETRAS',
#  'profesion_FOTOGRAFOS Y OPERADORES DE CAMARA CINE Y TV',
#  'profesion_GEOLOGIA',
#  'profesion_INGENIERIA ADMINISTRATIVA',
#  'profesion_INGENIERIA AGRICOLA',
#  'profesion_INGENIERIA AMBIENTAL',
#  'profesion_INGENIERIA CIVIL',
#  'profesion_INGENIERIA DE MINAS',
#  'profesion_INGENIERIA DE PETROLEOS',
#  'profesion_INGENIERIA DE SISTEMAS',
#  'profesion_INGENIERIA ELECTRICA',
#  'profesion_INGENIERIA FINANCIERA',
#  'profesion_INGENIERIA FORESTAL',
#  'profesion_INGENIERIA INDUSTRIAL',
#  'profesion_INGENIERIA MECANICA',
#  'profesion_INGENIERIA SANITARIA',
#  'profesion_INGENIERO',
#  'profesion_INGENIERO ELECTRONICO',
#  'profesion_INGENIERO METALURGICO',
#  'profesion_INGENIRIA QUIMICA',
#  'profesion_INSPECTORES DE ESTABLECIMIENTOS DE ENSEÑANZA',
#  'profesion_JOYERO',
#  'profesion_MEDICINA',
#  'profesion_MERCADOTECNIA',
#  'profesion_NINGUNA',
#  'profesion_NUTRICION Y DIETETICA',
#  'profesion_ODONTOLOGIA',
#  'profesion_OPERACIONES DE EQUIPOS MEDICOS',
#  'profesion_OTROS',
#  'profesion_PILOTOS',
#  'profesion_PROFESIONALES EN METODOS DIDACTICOS',
#  'profesion_PROFESORES DE EDUCACION ESPECIAL',
#  'profesion_PROFESORES DE EDUCACION PREESCOLAR',
#  'profesion_PROFESORES DE EDUCACION PRIMARIA',
#  'profesion_PSICOLOGIA',
#  'profesion_QUIMICA FARMACEUTICA',
#  'profesion_REGENCIA DE FARMACIA',
#  'profesion_RELIGIOSA',
#  'profesion_SACERDOTE',
#  'profesion_SECRETARIADO',
#  'profesion_SOCIOLOGIA',
#  'profesion_TECNOLOGIA AGROPECUARIA',
#  'profesion_TECNOLOGIA DEPORTIVA',
#  'profesion_TECNOLOGIA ELECTRICIDAD',
#  'profesion_TECNOLOGIA EN ADMINISTRACION',
#  'profesion_TECNOLOGIA EN CIENCIAS DE LA SALUD',
#  'profesion_TECNOLOGIA EN CONSTRUCCION',
#  'profesion_TECNOLOGIA EN MINAS',
#  'profesion_TECNOLOGIA INDUSTRIAL',
#  'profesion_TECNOLOGIA MECANICA',
#  'profesion_TECNOLOGIA SISTEMAS',
#  'profesion_TRABAJADORES DE ASISTENCIA SOCIAL',
#  'profesion_TRABAJO SOCIAL',
#  'profesion_TRANSPORTADOR',
#  'profesion_VETERINARIA',
#  'profesion_ZOOTECNIA',
#  'ocupacion_Comerciante',
#  'ocupacion_Desempleado con Ingresos',
#  'ocupacion_Desempleado sin Ingresos',
#  'ocupacion_Empleado',
#  'ocupacion_Estudiante',
#  'ocupacion_Independiente',
#  'ocupacion_Jubilado',
#  'ocupacion_Otro',
#  'ocupacion_Pensionado',
#  'ocupacion_Rentista de Capital',
#  'ciudad_residencia_#ANGUMA',
#  'ciudad_residencia_ABEJORRAL',
#  'ciudad_residencia_ABISINIA',
#  'ciudad_residencia_ABREGO',
#  'ciudad_residencia_ABRIAQUI',
#  'ciudad_residencia_ACACIAS',
#  'ciudad_residencia_ACANDI',
#  'ciudad_residencia_ACAPULCO',
#  'ciudad_residencia_ACEVEDO',
#  'ciudad_residencia_ACHI',
#  'ciudad_residencia_ACO',
#  'ciudad_residencia_AGRADO',
#  'ciudad_residencia_AGUA AZUL',
#  'ciudad_residencia_AGUA CLARA',
#  'ciudad_residencia_AGUA DE DIOS',
#  'ciudad_residencia_AGUA DULCE',
#  'ciudad_residencia_AGUABONITA',
#  'ciudad_residencia_AGUACHICA',
#  'ciudad_residencia_AGUACLARA',
#  'ciudad_residencia_AGUADAS',
#  'ciudad_residencia_AGUAS CLARAS',
#  'ciudad_residencia_AGUAZUL',
#  'ciudad_residencia_AGUSTIN CODAZZI',
#  'ciudad_residencia_AIPE',
#  'ciudad_residencia_ALBAN',
#  'ciudad_residencia_ALBANIA',
#  'ciudad_residencia_ALCALA',
#  'ciudad_residencia_ALDANA',
#  'ciudad_residencia_ALEJANDRIA',
#  'ciudad_residencia_ALFONSO LOPEZ',
#  'ciudad_residencia_ALGARROBO',
#  'ciudad_residencia_ALGECIRAS',
#  'ciudad_residencia_ALMAGUER',
#  'ciudad_residencia_ALPUJARRA',
#  'ciudad_residencia_ALTA VISTA',
#  'ciudad_residencia_ALTAGRACIA',
#  'ciudad_residencia_ALTAMIRA',
#  'ciudad_residencia_ALTO DE LA VIRGEN',
#  'ciudad_residencia_ALTO GRANDE',
#  'ciudad_residencia_ALVARADO',
#  'ciudad_residencia_AMAGA',
#  'ciudad_residencia_AMAIME',
#  'ciudad_residencia_AMALFI',
#  'ciudad_residencia_AMBALEMA',
#  'ciudad_residencia_ANAPOIMA',
#  'ciudad_residencia_ANCUYA',
#  'ciudad_residencia_ANDALUCIA',
#  'ciudad_residencia_ANDES',
#  'ciudad_residencia_ANGELOPOLIS',
#  'ciudad_residencia_ANGOSTURA',
#  'ciudad_residencia_ANGULO',
#  'ciudad_residencia_ANOLAIMA',
#  'ciudad_residencia_ANORI',
#  'ciudad_residencia_ANSERMA',
#  'ciudad_residencia_ANSERMANUEVO',
#  'ciudad_residencia_ANZA',
#  'ciudad_residencia_ANZOATEGUI',
#  'ciudad_residencia_APARTADO',
#  'ciudad_residencia_APIA',
#  'ciudad_residencia_APULO',
#  'ciudad_residencia_AQUITANIA',
#  'ciudad_residencia_ARABIA',
#  'ciudad_residencia_ARACATACA',
#  'ciudad_residencia_ARANZAZU',
#  'ciudad_residencia_ARATOCA',
#  'ciudad_residencia_ARAUCA',
#  'ciudad_residencia_ARAUQUITA',
#  'ciudad_residencia_ARBELAEZ',
#  'ciudad_residencia_ARBOLEDAS',
#  'ciudad_residencia_ARBOLETES',
#  'ciudad_residencia_ARCABUCO',
#  'ciudad_residencia_ARENAL',
#  'ciudad_residencia_ARGELIA',
#  'ciudad_residencia_ARIZAL',
#  'ciudad_residencia_ARJONA',
#  'ciudad_residencia_ARMA',
#  'ciudad_residencia_ARMENIA',
#  'ciudad_residencia_ARMENIA ABAJO',
#  'ciudad_residencia_ARMERO',
#  'ciudad_residencia_ARROYO DE PIEDRA',
#  'ciudad_residencia_ARROYO GRANDE',
#  'ciudad_residencia_ARROYOHONDO',
#  'ciudad_residencia_ASTREA',
#  'ciudad_residencia_ATACO',
#  'ciudad_residencia_AYAPEL',
#  'ciudad_residencia_BAGAZAL',
#  'ciudad_residencia_BAHIA HONDA',
#  'ciudad_residencia_BAHIA SOLANO',
#  'ciudad_residencia_BALBOA',
#  'ciudad_residencia_BARANOA',
#  'ciudad_residencia_BARATOA',
#  'ciudad_residencia_BARAYA',
#  'ciudad_residencia_BARBACOAS',
#  'ciudad_residencia_BARBOSA',
#  'ciudad_residencia_BARCELONA',
#  'ciudad_residencia_BARICHARA',
#  'ciudad_residencia_BARRAGAN',
#  'ciudad_residencia_BARRANCA',
#  'ciudad_residencia_BARRANCA DE UPIA',
#  'ciudad_residencia_BARRANCABERMEJA',
#  'ciudad_residencia_BARRANCAS',
#  'ciudad_residencia_BARRANCO DE LOBA',
#  'ciudad_residencia_BARRANCO MINAS',
#  'ciudad_residencia_BARRANQUILLA',
#  'ciudad_residencia_BARRANQUILLITA',
#  'ciudad_residencia_BARRIENTOS',
#  'ciudad_residencia_BARRIO OBRERO',
#  'ciudad_residencia_BARRIO PABLO NERUDA',
#  'ciudad_residencia_BARU',
#  'ciudad_residencia_BAYUNCA',
#  'ciudad_residencia_BECERRIL',
#  'ciudad_residencia_BELALCAZAR',
#  'ciudad_residencia_BELEN',
#  'ciudad_residencia_BELEN DE BAJIRA',
#  'ciudad_residencia_BELEN DE LOS ANDAQUIES',
#  'ciudad_residencia_BELEN DE UMBRIA',
#  'ciudad_residencia_BELENCITO',
#  'ciudad_residencia_BELLAVISTA',
#  'ciudad_residencia_BELLO',
#  'ciudad_residencia_BELLO HORIZONTE',
#  'ciudad_residencia_BELMIRA',
#  'ciudad_residencia_BELTRAN',
#  'ciudad_residencia_BERASTEGUI',
#  'ciudad_residencia_BERBEO',
#  'ciudad_residencia_BERRUECOS',
#  'ciudad_residencia_BESOTE',
#  'ciudad_residencia_BETANIA',
#  'ciudad_residencia_BETEITIVA',
#  'ciudad_residencia_BETULIA',
#  'ciudad_residencia_BITUIMA',
#  'ciudad_residencia_BOAVITA',
#  'ciudad_residencia_BOBAL',
#  'ciudad_residencia_BOCAS DE SATINGA',
#  'ciudad_residencia_BOCHALEMA',
#  'ciudad_residencia_BOCONO',
#  'ciudad_residencia_BOGOTA D.C.',
#  'ciudad_residencia_BOHIO',
#  'ciudad_residencia_BOJACA',
#  'ciudad_residencia_BOLIVAR',
#  'ciudad_residencia_BOLOMBOLO',
#  'ciudad_residencia_BONDA',
#  'ciudad_residencia_BONGO',
#  'ciudad_residencia_BOQUERON',
#  'ciudad_residencia_BORRERO AYERBE',
#  'ciudad_residencia_BOSCONIA',
#  'ciudad_residencia_BOYACA',
#  'ciudad_residencia_BRASIL',
#  'ciudad_residencia_BRICENO',
#  'ciudad_residencia_BRUSELAS',
#  'ciudad_residencia_BUCARAMANGA',
#  'ciudad_residencia_BUCARASICA',
#  'ciudad_residencia_BUENA VISTA',
#  'ciudad_residencia_BUENAVENTURA',
#  'ciudad_residencia_BUENAVISTA',
#  'ciudad_residencia_BUENAVISTICA',
#  'ciudad_residencia_BUENOS AIRES',
#  'ciudad_residencia_BUESACO',
#  'ciudad_residencia_BUESAQUILLO DOS',
#  'ciudad_residencia_BUGALAGRANDE',
#  'ciudad_residencia_BUJARAVITA',
#  'ciudad_residencia_BURITICA',
#  'ciudad_residencia_BUSBANZA',
#  'ciudad_residencia_CABA#AS',
#  'ciudad_residencia_CABRERA',
#  'ciudad_residencia_CABUYARO',
#  'ciudad_residencia_CACERES',
#  'ciudad_residencia_CACHIPAY',
#  'ciudad_residencia_CACHIRA',
#  'ciudad_residencia_CACOTA',
#  'ciudad_residencia_CAGUAN',
#  'ciudad_residencia_CAICEDO',
#  'ciudad_residencia_CAICEDONIA',
#  'ciudad_residencia_CAIMALITO',
#  'ciudad_residencia_CAIMITO',
#  'ciudad_residencia_CAJAMARCA',
#  'ciudad_residencia_CAJIBIO',
#  'ciudad_residencia_CAJICA',
#  'ciudad_residencia_CALABAZAS',
#  'ciudad_residencia_CALAHORRA',
#  'ciudad_residencia_CALAMAR',
#  'ciudad_residencia_CALARCA',
#  'ciudad_residencia_CALDAS',
#  'ciudad_residencia_CALDERA',
#  'ciudad_residencia_CALDONO',
#  'ciudad_residencia_CALERA',
#  'ciudad_residencia_CALI',
#  'ciudad_residencia_CALIBIO',
#  'ciudad_residencia_CALIFORNIA',
#  'ciudad_residencia_CALIMA',
#  'ciudad_residencia_CALOTO',
#  'ciudad_residencia_CAMARONES',
#  'ciudad_residencia_CAMBAO',
#  'ciudad_residencia_CAMPAMENTO',
#  'ciudad_residencia_CAMPECHE',
#  'ciudad_residencia_CAMPO ALEGRE',
#  'ciudad_residencia_CAMPO DE LA CRUZ',
#  'ciudad_residencia_CAMPOALEGRE',
#  'ciudad_residencia_CAMPOHERMOSO',
#  'ciudad_residencia_CANALETE',
#  'ciudad_residencia_CANASGORDAS',
#  'ciudad_residencia_CANDELARIA',
#  'ciudad_residencia_CANO DE AGUAS',
#  'ciudad_residencia_CANTAGALLO',
#  'ciudad_residencia_CAPARRAPI',
#  'ciudad_residencia_CAPELLANIA',
#  'ciudad_residencia_CAPITANEJO',
#  'ciudad_residencia_CAPURGANA',
#  'ciudad_residencia_CAQUEZA',
#  'ciudad_residencia_CARACOL',
#  'ciudad_residencia_CARACOLI',
#  'ciudad_residencia_CARAMANTA',
#  'ciudad_residencia_CARAZA',
#  'ciudad_residencia_CARCASI',
#  'ciudad_residencia_CAREPA',
#  'ciudad_residencia_CARLOSAMA',
#  'ciudad_residencia_CARMEN D ROVIRA',
#  'ciudad_residencia_CARMEN DE APICALA',
#  'ciudad_residencia_CARMEN DE ATRATO',
#  'ciudad_residencia_CARMEN DE CARUPA',
#  'ciudad_residencia_CARMEN DE VIBORAL',
#  'ciudad_residencia_CAROLINA',
#  'ciudad_residencia_CARRA',
#  'ciudad_residencia_CARRILLO',
#  'ciudad_residencia_CARTAGENA',
#  'ciudad_residencia_CARTAGENA DEL CHAIRA',
#  'ciudad_residencia_CARTAGENITA',
#  'ciudad_residencia_CARTAGO',
#  'ciudad_residencia_CARUPA',
#  'ciudad_residencia_CARURU',
#  'ciudad_residencia_CASABIANCA',
#  'ciudad_residencia_CASACARA',
#  'ciudad_residencia_CASAS VIEJAS',
#  'ciudad_residencia_CASTILLA LA NUEVA',
#  'ciudad_residencia_CASUARITO - PUERTO CARREÑO',
#  'ciudad_residencia_CATAMBUCO',
#  'ciudad_residencia_CATIVO',
#  'ciudad_residencia_CAUCA',
#  'ciudad_residencia_CAUCASIA',
#  'ciudad_residencia_CAÑAVERAL - SAN GIL',
#  'ciudad_residencia_CEJA',
#  'ciudad_residencia_CERETE',
#  'ciudad_residencia_CERINZA',
#  'ciudad_residencia_CERRITO',
#  'ciudad_residencia_CERRO SAN ANTONIO',
#  'ciudad_residencia_CERTEGUI',
#  'ciudad_residencia_CHACHAGUI',
#  'ciudad_residencia_CHAGUANI',
#  'ciudad_residencia_CHAMEZA',
#  'ciudad_residencia_CHAPARRAL',
#  'ciudad_residencia_CHARALA',
#  'ciudad_residencia_CHARTA',
#  'ciudad_residencia_CHIA',
#  'ciudad_residencia_CHICORAL',
#  'ciudad_residencia_CHIGORODO',
#  'ciudad_residencia_CHIGUERO',
#  'ciudad_residencia_CHIMA',
#  'ciudad_residencia_CHIMICHAGUA',
#  'ciudad_residencia_CHIMILA',
#  'ciudad_residencia_CHINACOTA',
#  'ciudad_residencia_CHINAUTA LOS PANCHES',
#  'ciudad_residencia_CHINAVITA',
#  'ciudad_residencia_CHINCHINA',
#  'ciudad_residencia_CHINU',
#  'ciudad_residencia_CHIPAQUE',
#  'ciudad_residencia_CHIPATA',
#  'ciudad_residencia_CHIQUINQUIRA',
#  'ciudad_residencia_CHIQUIZA',
#  'ciudad_residencia_CHIRIGUANA',
#  'ciudad_residencia_CHISCAS',
#  'ciudad_residencia_CHITA',
#  'ciudad_residencia_CHITAGA',
#  'ciudad_residencia_CHITARAQUE',
#  'ciudad_residencia_CHIVATA',
#  'ciudad_residencia_CHIVOLO',
#  'ciudad_residencia_CHIVOR',
#  'ciudad_residencia_CHOACHI',
#  'ciudad_residencia_CHOCHO SINCELEJO',
#  'ciudad_residencia_CHOCOA',
#  'ciudad_residencia_CHOCONTA',
#  'ciudad_residencia_CHUSCALITO',
#  'ciudad_residencia_CICUCO',
#  'ciudad_residencia_CIENAGA',
#  'ciudad_residencia_CIENAGA DE ORO',
#  'ciudad_residencia_CIENEGA',
#  'ciudad_residencia_CIMITARRA',
#  'ciudad_residencia_CIRCASIA',
#  'ciudad_residencia_CISNEROS',
#  'ciudad_residencia_CITE',
#  'ciudad_residencia_CIUDAD BOLIVAR',
#  'ciudad_residencia_CIUDAD EXTERIOR',
#  'ciudad_residencia_CLARINETERO',
#  'ciudad_residencia_CLEMENCIA',
#  'ciudad_residencia_COCONUCO',
#  'ciudad_residencia_COCORNA',
#  'ciudad_residencia_COELLO',
#  'ciudad_residencia_COGUA',
#  'ciudad_residencia_COLOMBIA',
#  'ciudad_residencia_COLON',
#  'ciudad_residencia_COMBIA',
#  'ciudad_residencia_COMBITA',
#  'ciudad_residencia_CONCEPCION',
#  'ciudad_residencia_CONCORDIA',
#  'ciudad_residencia_CONDOTO',
#  'ciudad_residencia_CONFINES',
#  'ciudad_residencia_CONSACA',
#  'ciudad_residencia_CONTADERO',
#  'ciudad_residencia_CONTRATACION',
#  'ciudad_residencia_CONVENCION',
#  'ciudad_residencia_COPACABANA',
#  'ciudad_residencia_COPER',
#  'ciudad_residencia_CORDOBA',
#  'ciudad_residencia_CORDOBA (NARIÑO)',
#  'ciudad_residencia_CORINTO',
#  'ciudad_residencia_CORNEJO',
#  'ciudad_residencia_COROMORO',
#  'ciudad_residencia_COROZAL',
#  'ciudad_residencia_CORRALES',
#  'ciudad_residencia_COSTA RICA',
#  'ciudad_residencia_COSTILLA',
#  'ciudad_residencia_COTA',
#  'ciudad_residencia_COTORRA',
#  'ciudad_residencia_COVENAS',
#  'ciudad_residencia_COVEÑAS',
#  'ciudad_residencia_COVEÑAS - TOLU',
#  'ciudad_residencia_COYAIMA',
#  'ciudad_residencia_CRAVO NORTE',
#  'ciudad_residencia_CRUCES',
#  'ciudad_residencia_CUBA',
#  'ciudad_residencia_CUBARA',
#  'ciudad_residencia_CUCAITA',
#  'ciudad_residencia_CUCUNUBA',
#  'ciudad_residencia_CUCUTA',
#  'ciudad_residencia_CUCUTILLA',
#  'ciudad_residencia_CUESTA RICA',
#  'ciudad_residencia_CUESTECITAS',
#  'ciudad_residencia_CUITIVA',
#  'ciudad_residencia_CUMARAL',
#  'ciudad_residencia_CUMARIBO',
#  'ciudad_residencia_CUMBAL',
#  'ciudad_residencia_CUNDAY',
#  'ciudad_residencia_CUPI',
#  'ciudad_residencia_CUPIAGUA',
#  'ciudad_residencia_CURBARADÓ - CARMEN DEL DARIÉN',
#  'ciudad_residencia_CURILLO',
#  'ciudad_residencia_CURITI',
#  'ciudad_residencia_CURRULAO',
#  'ciudad_residencia_CURUMANI',
#  'ciudad_residencia_DABEIBA',
#  'ciudad_residencia_DAGUA',
#  'ciudad_residencia_DAPA',
#  'ciudad_residencia_DARIEN',
#  'ciudad_residencia_DESAGUADERO',
#  'ciudad_residencia_DIBULLA',
#  'ciudad_residencia_DIBULLLA',
#  'ciudad_residencia_DISTRACCION',
#  'ciudad_residencia_DOLORES',
#  'ciudad_residencia_DON ALONSO',
#  'ciudad_residencia_DON MATIAS',
#  'ciudad_residencia_DORADAL',
#  'ciudad_residencia_DORADO',
#  'ciudad_residencia_DOS PE#AS',
#  'ciudad_residencia_DOS QUEBRADAS',
#  'ciudad_residencia_DOSQUEBRADAS',
#  'ciudad_residencia_DUITAMA',
#  'ciudad_residencia_DURANIA',
#  'ciudad_residencia_EBEJICO',
#  'ciudad_residencia_EDUARDO SANTOS',
#  'ciudad_residencia_EL AGUILA',
#  'ciudad_residencia_EL BAGRE',
#  'ciudad_residencia_EL BANCO',
#  'ciudad_residencia_EL BORDO',
#  'ciudad_residencia_EL CA#O',
#  'ciudad_residencia_EL CABUYAL',
#  'ciudad_residencia_EL CAIMO',
#  'ciudad_residencia_EL CAIRO',
#  'ciudad_residencia_EL CARITO',
#  'ciudad_residencia_EL CARMELO',
#  'ciudad_residencia_EL CARMEN',
#  'ciudad_residencia_EL CARMEN DE ATRATO',
#  'ciudad_residencia_EL CARMEN DE BOLIVAR',
#  'ciudad_residencia_EL CARMEN DE VIBORAL',
#  'ciudad_residencia_EL CASTILLO',
#  'ciudad_residencia_EL CENTRO',
#  'ciudad_residencia_EL CERRILLO',
#  'ciudad_residencia_EL CERRITO',
#  'ciudad_residencia_EL CHARCO',
#  'ciudad_residencia_EL CHOCO',
#  'ciudad_residencia_EL COCUY',
#  'ciudad_residencia_EL COLEGIO',
#  'ciudad_residencia_EL COPEY',
#  'ciudad_residencia_EL DIFICIL',
#  'ciudad_residencia_EL DONCELLO',
#  'ciudad_residencia_EL DORADO',
#  'ciudad_residencia_EL DOVIO',
#  'ciudad_residencia_EL ENCANTO',
#  'ciudad_residencia_EL ESPINO',
#  'ciudad_residencia_EL GUACAMAYO',
#  'ciudad_residencia_EL GUAMO',
#  'ciudad_residencia_EL HATO',
#  'ciudad_residencia_EL JUNCAL',
#  'ciudad_residencia_EL LIMON',
#  'ciudad_residencia_EL MANZANILLO',
#  'ciudad_residencia_EL MINGUEO',
#  'ciudad_residencia_EL MOLINO',
#  'ciudad_residencia_EL MORRO',
#  'ciudad_residencia_EL NARANJO',
#  'ciudad_residencia_EL OVERO',
#  'ciudad_residencia_EL PARAISO',
#  'ciudad_residencia_EL PASO',
#  'ciudad_residencia_EL PAUJIL',
#  'ciudad_residencia_EL PE#OL',
#  'ciudad_residencia_EL PENON',
#  'ciudad_residencia_EL PEÑOL (NARIÑO)',
#  'ciudad_residencia_EL PEÑON',
#  'ciudad_residencia_EL PITAL',
#  'ciudad_residencia_EL PIÑAL - LOS PALMITOS',
#  'ciudad_residencia_EL PIÑON',
#  'ciudad_residencia_EL PLACER',
#  'ciudad_residencia_EL PLAN',
#  'ciudad_residencia_EL PLAYON',
#  'ciudad_residencia_EL PORVENIR',
#  'ciudad_residencia_EL REPOSO',
#  'ciudad_residencia_EL RETEN',
#  'ciudad_residencia_EL RETIRO',
#  'ciudad_residencia_EL RETORNO',
#  'ciudad_residencia_EL RINCON DE GIRON',
#  'ciudad_residencia_EL ROBLE',
#  'ciudad_residencia_EL ROSAL',
#  'ciudad_residencia_EL ROSARIO',
#  'ciudad_residencia_EL SALADITO',
#  'ciudad_residencia_EL SANTUARIO',
#  'ciudad_residencia_EL SISGA',
#  'ciudad_residencia_EL TABLAZO',
#  'ciudad_residencia_EL TABLON',
#  'ciudad_residencia_EL TAMBO',
#  'ciudad_residencia_EL TAMBO (NARIÑO)',
#  'ciudad_residencia_EL TARRA',
#  'ciudad_residencia_EL TOTUMO',
#  'ciudad_residencia_EL TRES',
#  'ciudad_residencia_EL VALLE',
#  'ciudad_residencia_EL ZULIA',
#  'ciudad_residencia_ELIAS',
#  'ciudad_residencia_ENCENILLA',
#  'ciudad_residencia_ENCISO',
#  'ciudad_residencia_ENTRERRIOS',
#  'ciudad_residencia_ENVIGADO',
#  'ciudad_residencia_ERANILLO - EL PIÑON',
#  'ciudad_residencia_ESPINAL',
#  'ciudad_residencia_ESTADOS UNIDOS',
#  'ciudad_residencia_EVITAR',
#  'ciudad_residencia_FACATATIVA',
#  'ciudad_residencia_FALAN',
#  'ciudad_residencia_FARALLONES',
#  'ciudad_residencia_FATIMA',
#  'ciudad_residencia_FELIDIA',
#  'ciudad_residencia_FENICIA',
#  'ciudad_residencia_FILADELFIA',
#  'ciudad_residencia_FILANDIA',
#  'ciudad_residencia_FINLANDIA',
#  'ciudad_residencia_FIRAVITOBA',
#  'ciudad_residencia_FLANDES',
#  'ciudad_residencia_FLORENCIA',
#  'ciudad_residencia_FLORESTA',
#  'ciudad_residencia_FLORIAN',
#  'ciudad_residencia_FLORIDA',
#  'ciudad_residencia_FLORIDABLANCA',
#  'ciudad_residencia_FOMEQUE',
#  'ciudad_residencia_FONSECA',
#  'ciudad_residencia_FORTUL',
#  'ciudad_residencia_FOSCA',
#  'ciudad_residencia_FRAILES',
#  'ciudad_residencia_FREDONIA',
#  'ciudad_residencia_FRESNO',
#  'ciudad_residencia_FRONTINO',
#  'ciudad_residencia_FUENTE DE ORO',
#  'ciudad_residencia_FUNDACION',
#  'ciudad_residencia_FUNES',
#  'ciudad_residencia_FUNZA',
#  'ciudad_residencia_FUQUENE',
#  'ciudad_residencia_FUSAGASUGA',
#  'ciudad_residencia_GACHALA',
#  'ciudad_residencia_GACHANCIPA',
#  'ciudad_residencia_GACHANTIVA',
#  'ciudad_residencia_GACHETA',
#  'ciudad_residencia_GAIRA',
#  'ciudad_residencia_GAITANIA',
#  'ciudad_residencia_GALAN',
#  'ciudad_residencia_GALAPA',
#  'ciudad_residencia_GALERAS',
#  'ciudad_residencia_GALINDEZ',
#  'ciudad_residencia_GAMA',
#  'ciudad_residencia_GAMARRA',
#  'ciudad_residencia_GAMBITA',
#  'ciudad_residencia_GAMBOTE',
#  'ciudad_residencia_GAMEZA',
#  'ciudad_residencia_GARAGOA',
#  'ciudad_residencia_GARAVITO',
#  'ciudad_residencia_GARZON',
#  'ciudad_residencia_GAZABINA',
#  'ciudad_residencia_GENOVA',
#  'ciudad_residencia_GENOY',
#  'ciudad_residencia_GIGANTE',
#  'ciudad_residencia_GINEBRA',
#  'ciudad_residencia_GIRALDO',
#  'ciudad_residencia_GIRARDOT',
#  'ciudad_residencia_GIRARDOTA',
#  'ciudad_residencia_GIRON',
#  'ciudad_residencia_GIRON DEL RESGUARDO',
#  'ciudad_residencia_GOMEZ PLATA',
#  'ciudad_residencia_GONZALEZ',
#  'ciudad_residencia_GRAMALOTE',
#  'ciudad_residencia_GRANADA',
#  'ciudad_residencia_GRANADA EL SOCHE',
#  'ciudad_residencia_GRATAMIRA',
#  'ciudad_residencia_GUACAMAYAL',
#  'ciudad_residencia_GUACAMAYAS',
#  'ciudad_residencia_GUACARI',
#  'ciudad_residencia_GUACAS',
#  'ciudad_residencia_GUACHACA',
#  'ciudad_residencia_GUACHENE',
#  'ciudad_residencia_GUACHENÉ',
#  'ciudad_residencia_GUACHETA',
#  'ciudad_residencia_GUACHICONO',
#  'ciudad_residencia_GUACHUCAL',
#  'ciudad_residencia_GUADALAJARA DE BUGA',
#  'ciudad_residencia_GUADALUPE',
#  'ciudad_residencia_GUADUAS',
#  'ciudad_residencia_GUAITARILLA',
#  'ciudad_residencia_GUALANDAY',
#  'ciudad_residencia_GUALMATAN',
#  'ciudad_residencia_GUAMAL',
#  'ciudad_residencia_GUAMALITO',
#  'ciudad_residencia_GUAMO',
#  'ciudad_residencia_GUANABANAL',
#  'ciudad_residencia_GUAPI',
#  'ciudad_residencia_GUAPOTA',
#  'ciudad_residencia_GUARANDA',
#  'ciudad_residencia_GUARINOCITO',
#  'ciudad_residencia_GUARNE',
#  'ciudad_residencia_GUARUMO',
#  'ciudad_residencia_GUASCA',
#  'ciudad_residencia_GUASIMALITO',
#  'ciudad_residencia_GUATAPE',
#  'ciudad_residencia_GUATAVITA',
#  'ciudad_residencia_GUATEQUE',
#  'ciudad_residencia_GUATICA',
#  'ciudad_residencia_GUAVATA',
#  'ciudad_residencia_GUAVIO ALTO',
#  'ciudad_residencia_GUAYABAL',
#  'ciudad_residencia_GUAYABAL DE SIQUIMA',
#  'ciudad_residencia_GUAYABETAL',
#  'ciudad_residencia_GUAYATA',
#  'ciudad_residencia_GUEPSA',
#  'ciudad_residencia_GUICAN',
#  'ciudad_residencia_HATO COROZAL',
#  'ciudad_residencia_HATO GRANDE',
#  'ciudad_residencia_HATONUEVO',
#  'ciudad_residencia_HELICONIA',
#  'ciudad_residencia_HERVEO',
#  'ciudad_residencia_HISPANIA',
#  'ciudad_residencia_HOBO',
#  'ciudad_residencia_HOLANDA',
#  'ciudad_residencia_HONDA',
#  'ciudad_residencia_HUERTAS',
#  'ciudad_residencia_HUILA',
#  'ciudad_residencia_HUMADEA',
#  'ciudad_residencia_IBAGUE',
#  'ciudad_residencia_ICONONZO',
#  'ciudad_residencia_ILES',
#  'ciudad_residencia_IMUES',
#  'ciudad_residencia_INIRIDA',
#  'ciudad_residencia_INZA',
#  'ciudad_residencia_IPIALES',
#  'ciudad_residencia_IPIALES - NARIÑO',
#  'ciudad_residencia_IQUIRA',
#  'ciudad_residencia_IRRA',
#  'ciudad_residencia_ISLA DEL ROSARIO',
#  'ciudad_residencia_ISLA FUERTE',
#  'ciudad_residencia_ISLA GRANDE',
#  'ciudad_residencia_ISMAEL PERDOMO',
#  'ciudad_residencia_ISNOS',
#  'ciudad_residencia_ISTMINA',
#  'ciudad_residencia_ITAGUI',
#  'ciudad_residencia_ITUANGO',
#  'ciudad_residencia_IZA',
#  'ciudad_residencia_JAGUA DEL PILAR',
#  'ciudad_residencia_JAMBALO',
#  'ciudad_residencia_JAMONDINO',
#  'ciudad_residencia_JAMUNDI',
#  'ciudad_residencia_JARDIN',
#  'ciudad_residencia_JENESANO',
#  'ciudad_residencia_JERICO',
#  'ciudad_residencia_JERUSALEN',
#  'ciudad_residencia_JESUS MARIA',
#  'ciudad_residencia_JONGOBITO',
#  'ciudad_residencia_JUAN ARIAS',
#  'ciudad_residencia_JUAN DE ACOSTA',
#  'ciudad_residencia_JUAN MINA',
#  'ciudad_residencia_JUANCHITO',
#  'ciudad_residencia_JUNIN',
#  'ciudad_residencia_JURADO -',
#  'ciudad_residencia_LA APARTADA',
#  'ciudad_residencia_LA ARGENTINA',
#  'ciudad_residencia_LA AURORA',
#  'ciudad_residencia_LA BELLA',
#  'ciudad_residencia_LA BELLEZA',
#  'ciudad_residencia_LA BOQUILLA',
#  'ciudad_residencia_LA BUITRERA',
#  'ciudad_residencia_LA CALERA',
#  'ciudad_residencia_LA CALLEJA',
#  'ciudad_residencia_LA CAPILLA',
#  'ciudad_residencia_LA CEDRONA',
#  'ciudad_residencia_LA CEJA',
#  'ciudad_residencia_LA CEJITA',
#  'ciudad_residencia_LA CELIA',
#  'ciudad_residencia_LA CHAPARRERA',
#  'ciudad_residencia_LA CHINA',
#  'ciudad_residencia_LA CHORRERA',
#  'ciudad_residencia_LA CRUZ',
#  'ciudad_residencia_LA CRUZADA',
#  'ciudad_residencia_LA CUCHILLA',
#  'ciudad_residencia_LA CUMBRE',
#  'ciudad_residencia_LA DOLORES',
#  'ciudad_residencia_LA DORADA',
#  'ciudad_residencia_LA ESPERANZA',
#  'ciudad_residencia_LA ESTRELLA',
#  'ciudad_residencia_LA FLORESTA',
#  'ciudad_residencia_LA FLORIDA',
#  'ciudad_residencia_LA GALLERA',
#  'ciudad_residencia_LA GLORIA',
#  'ciudad_residencia_LA GOMEZ',
#  'ciudad_residencia_LA GRAN VIA',
#  'ciudad_residencia_LA GUAYACANA',
#  'ciudad_residencia_LA HORMIGA',
#  'ciudad_residencia_LA INMACULADA',
#  'ciudad_residencia_LA JAGUA DE IBIRICO',
#  'ciudad_residencia_LA JAGUA DEL PILAR',
#  'ciudad_residencia_LA LINDA',
#  'ciudad_residencia_LA LLANADA',
#  'ciudad_residencia_LA LOMA',
#  'ciudad_residencia_LA MACARENA',
#  'ciudad_residencia_LA MARGARITA',
#  'ciudad_residencia_LA MARIA',
#  'ciudad_residencia_LA MATA',
#  'ciudad_residencia_LA MERCED',
#  'ciudad_residencia_LA MESA',
#  'ciudad_residencia_LA MILAGROSA',
#  'ciudad_residencia_LA MONTAÑITA',
#  'ciudad_residencia_LA PAILA',
#  'ciudad_residencia_LA PALMA',
#  'ciudad_residencia_LA PALMA  C/MARCA',
#  'ciudad_residencia_LA PALMITA',
#  'ciudad_residencia_LA PASCUALA',
#  'ciudad_residencia_LA PAZ',
#  'ciudad_residencia_LA PENA',
#  'ciudad_residencia_LA PINTADA',
#  'ciudad_residencia_LA PLATA',
#  'ciudad_residencia_LA PLATA (ARGELIA',
#  'ciudad_residencia_LA PLAYA',
#  'ciudad_residencia_LA PLAYITA',
#  'ciudad_residencia_LA PRADERA',
#  'ciudad_residencia_LA PRIMAVERA',
#  'ciudad_residencia_LA SALINA',
#  'ciudad_residencia_LA SIERRA',
#  'ciudad_residencia_LA SIERRA (PTO NARE',
#  'ciudad_residencia_LA SOLEDAD',
#  'ciudad_residencia_LA TABLAZA',
#  'ciudad_residencia_LA TEBAIDA',
#  'ciudad_residencia_LA UNION',
#  'ciudad_residencia_LA UNION (NARIÑO)',
#  'ciudad_residencia_LA UVITA',
#  'ciudad_residencia_LA VEGA',
#  'ciudad_residencia_LA VICTORIA',
#  'ciudad_residencia_LA VIRGINIA',
#  'ciudad_residencia_LA YE',
#  'ciudad_residencia_LABATECA',
#  'ciudad_residencia_LANDAZURI',
#  'ciudad_residencia_LAS MERCEDES',
#  'ciudad_residencia_LAS PALMAS',
#  'ciudad_residencia_LAS PEÑAS - COROZAL',
#  'ciudad_residencia_LEBRIJA',
#  'ciudad_residencia_LEIVA',
#  'ciudad_residencia_LEJANIAS',
#  'ciudad_residencia_LENA',
#  'ciudad_residencia_LENGUAZAQUE',
#  'ciudad_residencia_LERIDA',
#  'ciudad_residencia_LETICIA',
#  'ciudad_residencia_LIBANO',
#  'ciudad_residencia_LIBORINA',
#  'ciudad_residencia_LINARES',
#  'ciudad_residencia_LLANO GRANDE',
#  'ciudad_residencia_LLANOS DE CUIBA',
#  'ciudad_residencia_LLANOS DE CUIVA',
#  'ciudad_residencia_LLORENTE',
#  'ciudad_residencia_LLORO',
#  'ciudad_residencia_LOBO GUERRERO',
#  'ciudad_residencia_LOMA CORREDOR',
#  'ciudad_residencia_LOMA DE ARENA',
#  'ciudad_residencia_LOMITAS',
#  'ciudad_residencia_LORICA',
#  'ciudad_residencia_LOS ANDES',
#  'ciudad_residencia_LOS CAUCHOS',
#  'ciudad_residencia_LOS CHANCOS',
#  'ciudad_residencia_LOS CORDOBAS',
#  'ciudad_residencia_LOS GARSONES',
#  'ciudad_residencia_LOS LIMONES',
#  'ciudad_residencia_LOS PALMITOS',
#  'ciudad_residencia_LOS PATIOS',
#  'ciudad_residencia_LOS PATIOS NORTE DE SANTANDER',
#  'ciudad_residencia_LOS SANTOS',
#  'ciudad_residencia_LURUACO',
#  'ciudad_residencia_MACAJAN',
#  'ciudad_residencia_MACANAL',
#  'ciudad_residencia_MACARAVITA',
#  'ciudad_residencia_MACEO',
#  'ciudad_residencia_MACHETA',
#  'ciudad_residencia_MADRID',
#  'ciudad_residencia_MADRIGAL',
#  'ciudad_residencia_MAGANGUE',
#  'ciudad_residencia_MAGUARE',
#  'ciudad_residencia_MAHATES',
#  'ciudad_residencia_MAICAO',
#  'ciudad_residencia_MAJAGUAL',
#  'ciudad_residencia_MALAGA',
#  'ciudad_residencia_MALAGANA',
#  'ciudad_residencia_MALAMBO',
#  'ciudad_residencia_MANAGRU',
#  'ciudad_residencia_MANATI',
#  'ciudad_residencia_MANAURE',
#  'ciudad_residencia_MANAURE BALCON DL CESAR',
#  'ciudad_residencia_MANI',
#  'ciudad_residencia_MANIZALES',
#  'ciudad_residencia_MANTA',
#  'ciudad_residencia_MANZANARES',
#  'ciudad_residencia_MAPIRIPAN',
#  'ciudad_residencia_MARANDUA',
#  'ciudad_residencia_MARIA LA BAJA',
#  'ciudad_residencia_MARINILLA',
#  'ciudad_residencia_MARIPI',
#  'ciudad_residencia_MARIQUITA',
#  'ciudad_residencia_MARIQUITA - OCAÑA',
#  'ciudad_residencia_MARMATO',
#  'ciudad_residencia_MARQUETALIA',
#  'ciudad_residencia_MARSELLA',
#  'ciudad_residencia_MARULANDA',
#  'ciudad_residencia_MATANZA',
#  'ciudad_residencia_MAYA',
#  'ciudad_residencia_MEDELLIN',
#  'ciudad_residencia_MEDELLIN DEL ARIARI',
#  'ciudad_residencia_MEDIA CUESTA',
#  'ciudad_residencia_MEDIACANOA',
#  'ciudad_residencia_MEDINA',
#  'ciudad_residencia_MEDIO SAN JUAN',
#  'ciudad_residencia_MELGAR',
#  'ciudad_residencia_MERCADERES',
#  'ciudad_residencia_MESA',
#  'ciudad_residencia_MESA DE SANTOS',
#  'ciudad_residencia_MESETA SAN RAFAEL',
#  'ciudad_residencia_MESETAS',
#  'ciudad_residencia_MESITAS',
#  'ciudad_residencia_MESOPOTAMIA',
#  'ciudad_residencia_MEXICO',
#  'ciudad_residencia_MIAMI',
#  'ciudad_residencia_MICAY',
#  'ciudad_residencia_MINAS',
#  'ciudad_residencia_MINCA',
#  'ciudad_residencia_MIRABUENO',
#  'ciudad_residencia_MIRAFLORES',
#  'ciudad_residencia_MIRANDA',
#  'ciudad_residencia_MISTRATO',
#  'ciudad_residencia_MITU',
#  'ciudad_residencia_MOCOA',
#  'ciudad_residencia_MOGOTES',
#  'ciudad_residencia_MOLAGAVITA',
#  'ciudad_residencia_MOMIL',
#  'ciudad_residencia_MOMPOS',
#  'ciudad_residencia_MONDOMO',
#  'ciudad_residencia_MONGUA',
#  'ciudad_residencia_MONGUI',
#  'ciudad_residencia_MONIQUIRA',
#  'ciudad_residencia_MONTEBELLO',
#  'ciudad_residencia_MONTECRISTO',
#  'ciudad_residencia_MONTELIBANO',
#  'ciudad_residencia_MONTENEGRO',
#  'ciudad_residencia_MONTERA',
#  'ciudad_residencia_MONTERIA',
#  'ciudad_residencia_MONTERREY',
#  'ciudad_residencia_MORALES',
#  'ciudad_residencia_MORELIA',
#  'ciudad_residencia_MORICHAL',
#  'ciudad_residencia_MORROA',
#  'ciudad_residencia_MOSQUERA',
#  'ciudad_residencia_MOSQUERA (NARIÑO)',
#  'ciudad_residencia_MOTAVITA',
#  'ciudad_residencia_MOÑITOS',
#  'ciudad_residencia_MULALO',
#  'ciudad_residencia_MURILLO',
#  'ciudad_residencia_MURINDO',
#  'ciudad_residencia_MUSICHY',
#  'ciudad_residencia_MUTATA',
#  'ciudad_residencia_MUTIS',
#  'ciudad_residencia_MUTISCUA',
#  'ciudad_residencia_MUZO',
#  'ciudad_residencia_NARANJAL',
#  'ciudad_residencia_NARINO',
#  'ciudad_residencia_NARIÑO - CALDAS',
#  'ciudad_residencia_NARIÑO - LEIVA',
#  'ciudad_residencia_NARIÑO - NARIÑO',
#  'ciudad_residencia_NARIÑO - PASTO',
#  'ciudad_residencia_NARIÑO - TULUA',
#  'ciudad_residencia_NATAGA',
#  'ciudad_residencia_NATAGAIMA',
#  'ciudad_residencia_NAZARETH',
#  'ciudad_residencia_NECHI',
#  'ciudad_residencia_NECOCLI',
#  'ciudad_residencia_NEIRA',
#  'ciudad_residencia_NEIVA',
#  'ciudad_residencia_NEMOCON',
#  'ciudad_residencia_NILO',
#  'ciudad_residencia_NIMAIMA',
#  'ciudad_residencia_NIQUIA',
#  'ciudad_residencia_NOBSA',
#  'ciudad_residencia_NOCAIMA',
#  'ciudad_residencia_NORCASIA',
#  'ciudad_residencia_NOROSI',
#  'ciudad_residencia_NUEVA COLONIA',
#  'ciudad_residencia_NUEVA ERA',
#  'ciudad_residencia_NUEVA GRANADA',
#  'ciudad_residencia_NUEVO COLON',
#  'ciudad_residencia_NUNCHIA',
#  'ciudad_residencia_NUNEZ',
#  'ciudad_residencia_NUQUI',
#  'ciudad_residencia_OBANDO',
#  'ciudad_residencia_OBONUCO',
#  'ciudad_residencia_OCA#A',
#  'ciudad_residencia_OCAMONTE',
#  'ciudad_residencia_OCAÑA',
#  'ciudad_residencia_OIBA',
#  ...]

# %%
df_onehot.shape
# Out:
# (1092553, 1604)

# %%
100*df_onehot[features_f].isnull().sum()/df_onehot.shape[0]
# Out:
# edad                                    0.0
# mora_max                                0.0
# cant_moras_30_ult_12_meses              0.0
# cant_moras_60_ult_12_meses              0.0
# cant_moras_90_ult_12_meses              0.0
# cupo_total_tc                           0.0
# codigo_ciiu                             0.0
# ctas_activas                            0.0
# ctas_embargadas                         0.0
# mediana_nom3                            0.0
# cant_mora_30_tdc_ult_3m_sf              0.0
# cant_mora_30_consum_ult_3m_sf           0.0
# mediana_nom3_desv                       0.0
# mediana_pen3_desv                       0.0
# ingreso_nompen_desv                     0.0
# ingreso_final_desv                      0.0
# ingreso_nompen                          0.0
# ingreso_final                           0.0
# cuota_de_vivienda                       0.0
# cuota_de_consumo                        0.0
# cuota_rotativos                         0.0
# cuota_de_sector_solidario               0.0
# cuota_sector_real_comercio              0.0
# pol_centr_ext                           0.0
# saldo_prom3_tdc_mdo                     0.0
# cupo_tc_mdo                             0.0
# cant_oblig_tot_sf                       0.0
# cant_cast_ult_12m_sr                    0.0
# saldo_no_rot_mdo                        0.0
# ind                                     0.0
# gasto_familiar                          0.0
# ciudad_residencia_tag_ind               0.0
# ciudad_residencia_tag_gasto_familiar    0.0
# ciudad_residencia_tag_ingreso_nompen    0.0
# dtype: float64

# %% [markdown]
# # PCA - _Principal Component Analysis_

# %%
Estandar = StandardScaler()
Estandar.fit(df_onehot)

df_std = Estandar.transform(df_onehot)
df_std = pd.DataFrame(df_std)
round(df_std.describe().T,2)
# Out:
#           count  mean  std   min   25%   50%   75%     max
# 0     1092553.0  -0.0  1.0 -1.67 -0.80 -0.22  0.59    5.69
# 1     1092553.0  -0.0  1.0 -0.26 -0.26 -0.26 -0.23  109.55
# 2     1092553.0   0.0  1.0 -0.17 -0.17 -0.17 -0.17   14.42
# 3     1092553.0  -0.0  1.0 -0.12 -0.12 -0.12 -0.12   18.71
# 4     1092553.0  -0.0  1.0 -0.09 -0.09 -0.09 -0.09   22.66
# ...         ...   ...  ...   ...   ...   ...   ...     ...
# 1599  1092553.0  -0.0  1.0 -0.40 -0.40 -0.40 -0.40    2.51
# 1600  1092553.0   0.0  1.0 -0.30 -0.30 -0.30 -0.30    3.29
# 1601  1092553.0   0.0  1.0 -0.20 -0.20 -0.20 -0.20    4.95
# 1602  1092553.0   0.0  1.0 -0.36 -0.36 -0.36 -0.36    2.80
# 1603  1092553.0  -0.0  1.0 -0.20 -0.20 -0.20 -0.20    4.94
#
# [1604 rows x 8 columns]

# %%
autovalores, autovectores = np.linalg.eig(df_std.T.dot(df_std))

# %%
PCA = pd.DataFrame(columns = ['Variable','Autovalor'])
PCA['Variable'] = df_onehot.columns
PCA['Autovalor'] = autovalores.real
PCA = PCA.sort_values(by=('Autovalor'), ascending=False)
PCA.head(30)
# Out:
#                            Variable     Autovalor
# 0                              edad  1.092553e+07
# 1                          mora_max  6.584764e+06
# 2        cant_moras_30_ult_12_meses  4.840110e+06
# 3        cant_moras_60_ult_12_meses  4.489498e+06
# 4        cant_moras_90_ult_12_meses  4.042211e+06
# 5                     cupo_total_tc  3.950269e+06
# 6                       codigo_ciiu  3.740241e+06
# 7                      ctas_activas  3.530504e+06
# 8                   ctas_embargadas  3.086976e+06
# 9                      mediana_nom3  2.570401e+06
# 10                 ind_mora_vigente  2.434377e+06
# 11                cartera_castigada  2.228145e+06
# 13                    tiene_consumo  2.156213e+06
# 15               tiene_ctas_activas  2.007916e+06
# 16            tiene_ctas_embargadas  1.906831e+06
# 20       cant_mora_30_tdc_ult_3m_sf  1.796140e+06
# 22                mediana_nom3_desv  1.713109e+06
# 25               ingreso_final_desv  1.604018e+06
# 27                    ingreso_final  1.551781e+06
# 62              estado_civil_CASADO  1.479604e+06
# 63          estado_civil_DIVORCIADO  1.456065e+06
# 64             estado_civil_SOLTERO  1.413544e+06
# 65         estado_civil_UNION LIBRE  1.396221e+06
# 67        nivel_academico_BACHILLER  1.360423e+06
# 68  nivel_academico_ESPECIALIZACION  1.351523e+06
# 71        nivel_academico_TECNOLOGO  1.288563e+06
# 72    nivel_academico_UNIVERSITARIO  1.283676e+06
# 74              profesion_AGRONOMIA  1.263585e+06
# 75           profesion_ARQUITECTURA  1.256561e+06
# 77      profesion_AUXILIAR CONTABLE  1.226053e+06

# %%
plt.rcParams.update({'font.size': 20})
sns.set_style('darkgrid')
plt.style.use("dark_background")
plt.figure(figsize=(10,40))
y = np.array(list(PCA['Variable'].head(100)))
x = np.array(list(PCA['Autovalor'].head(100)))
sns.barplot(x=x, y=y, palette="viridis")
plt.title("Componentes Principales")
# Out:
# Text(0.5, 1.0, 'Componentes Principales')

# %%
PCA.to_csv("/mnt/workstation/data/PCA.csv", index=False)
